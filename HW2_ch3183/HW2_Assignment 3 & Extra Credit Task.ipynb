# %%
import os
import sys
import pandas as pd
import pylab as pl
import numpy as np
import datetime as dt
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')

# %%
os.getenv("DFDATA")

# %%
#use pandas read data
data=pd.read_csv(os.getenv("DFDATA")+'/jmje-u6e9/1476471465/jmje-u6e9.csv')

# %%
#display top few lines of data
data.head()

# %%
reduced_data=data[["LATITUDE","LONGITUDE"]]
reduced_data.head()

# %%
#drop the rows with all "NaN"
reduced_data.dropna(axis=0,how="all")

# %%
plt.figure()
plt.title("Location",fontsize=16)
plt.scatter(reduced_data.LONGITUDE, reduced_data.LATITUDE)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %% [markdown]
# #Extra Credit Task

# %%
#use pandas read data
data2=pd.read_csv(os.getenv("DFDATA")+'/dvm6-udsa/1473437627/dvm6-udsa.csv',nrows=500)

# %%
data2.head()
# Out:
#   Ticket Number Violation Date Violation Time        Issuing Agency  \
# 0    040445863X     12/22/2012       01:46:00     SANITATION POLICE
# 1    040426052Z     07/09/2012       03:38:00     SANITATION POLICE
# 2    040380790J     05/10/2007       12:27:00  SANITATION RECYCLING
# 3    040491275R     07/11/2007       16:27:00     SANITATION POLICE
# 4    040494029P     02/18/2009       09:42:00  SANITATION RECYCLING
#
#    Respondent Last Name Respondent First Name Balance Due  \
# 0               ADERDOR                  SAID     $385.00
# 1                  RYAD                 MAGDY       $0.00
# 2  COMPUTIME INC PROFIT                   NaN       $0.00
# 3      509 CHAUNCEY LLC                   NaN       $0.00
# 4                   ALI         SHEHZAD ANWAR       $0.00
#
#   Violation Location (Borough)  Violation Location (Block No.)  \
# 0                    MANHATTAN                             NaN
# 1                    MANHATTAN                             NaN
# 2                     BROOKLYN                          1992.0
# 3                     BROOKLYN                          1511.0
# 4                     BROOKLYN                          3187.0
#
#    Violation Location (Lot No.)             ...               \
# 0                           NaN             ...
# 1                           NaN             ...
# 2                          24.0             ...
# 3                          71.0             ...
# 4                          38.0             ...
#
#   Compliance Status Violation Description  Charge #1: Code  \
# 0       Penalty Due                   NaN             AH3G
# 1     All Terms Met                   NaN             AH3G
# 2     All Terms Met                   NaN             AH50
# 3     All Terms Met                   NaN             AH50
# 4     All Terms Met                   NaN             AH50
#
#   Charge #1: Code Section                  Charge #1: Code Description  \
# 0            H.C. 89.25 A  IMPROPER GARBAGE COLLECTION AND OR DISPOSAL
# 1            H.C. 89.25 A  IMPROPER GARBAGE COLLECTION AND OR DISPOSAL
# 2           H.C. 151.03 A                              RAT INFESTATION
# 3           H.C. 151.03 A                              RAT INFESTATION
# 4           H.C. 151.03 A                              RAT INFESTATION
#
#   Charge #1: Infraction Amount Charge #2: Code Charge #2: Code Section  \
# 0                      $385.00             NaN                     NaN
# 1                      $385.00             NaN                     NaN
# 2                      $200.00             NaN                     NaN
# 3                      $200.00             NaN                     NaN
# 4                      $200.00             NaN                     NaN
#
#   Charge #2: Code Description Charge #2: Infraction Amount
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
# [5 rows x 46 columns]

# %%
data2.dropna(axis=0,how="all")
# Out:
#     Ticket Number Violation Date Violation Time            Issuing Agency  \
# 0      040445863X     12/22/2012       01:46:00         SANITATION POLICE
# 1      040426052Z     07/09/2012       03:38:00         SANITATION POLICE
# 2      040380790J     05/10/2007       12:27:00      SANITATION RECYCLING
# 3      040491275R     07/11/2007       16:27:00         SANITATION POLICE
# 4      040494029P     02/18/2009       09:42:00      SANITATION RECYCLING
# 5      040512326H     03/07/2009       17:45:00         SANITATION POLICE
# 6      043128167M     01/13/2016       13:38:00  DOS - ENFORCEMENT AGENTS
# 7      040542172L     01/30/2008       10:19:00      SANITATION RECYCLING
# 8      040400039Z     12/21/2006       11:35:00      SANITATION RECYCLING
# 9      040420994P     06/19/2007       09:19:00      SANITATION RECYCLING
# 10     040694894X     07/12/2012       11:24:00  DOS - ENFORCEMENT AGENTS
# 11     040784187X     10/12/2011       13:45:00  DOS - ENFORCEMENT AGENTS
# 12     040793244H     07/20/2011       14:34:00  DOS - ENFORCEMENT AGENTS
# 13     040794208P     02/22/2012       11:45:00  DOS - ENFORCEMENT AGENTS
# 14     0190822327     02/09/2016       18:00:00         POLICE DEPARTMENT
# 15     0190822336     02/09/2016       18:00:00         POLICE DEPARTMENT
# 16     0190822345     02/09/2016       19:25:00         POLICE DEPARTMENT
# 17     0190825068     02/11/2016       18:00:00         POLICE DEPARTMENT
# 18     0190841090     02/11/2016       12:40:00         POLICE DEPARTMENT
# 19     0190825214     02/09/2016       19:25:00         POLICE DEPARTMENT
# 20     0190825223     02/09/2016       19:25:00         POLICE DEPARTMENT
# 21     0190841128     02/11/2016       12:40:00         POLICE DEPARTMENT
# 22     0190841586     02/12/2016       15:40:00         POLICE DEPARTMENT
# 23     0190842017     02/10/2016       14:17:00         POLICE DEPARTMENT
# 24     0190842026     02/10/2016       14:17:00         POLICE DEPARTMENT
# 25     0190841540     02/10/2016       11:36:00         POLICE DEPARTMENT
# 26     0190842255     02/10/2016       14:17:00         POLICE DEPARTMENT
# 27     0191086161     02/15/2016       18:50:00         POLICE DEPARTMENT
# 28     0191089957     02/10/2016       16:20:00         POLICE DEPARTMENT
# 29     0191089948     02/10/2016       17:05:00         POLICE DEPARTMENT
# ..            ...            ...            ...                       ...
# 470    0800418668     09/16/2013       14:55:00          VETERINARY-DOHMH
# 471    0800418823     09/11/2013       14:54:00          VETERINARY-DOHMH
# 472    0800418924     09/16/2013       11:39:00          VETERINARY-DOHMH
# 473    0800430007     10/17/2013       19:01:00          BED BUGS - DOHMH
# 474    0800430016     10/17/2013       19:01:00          BED BUGS - DOHMH
# 475    0800452932     12/19/2013       19:00:00          BED BUGS - DOHMH
# 476    0183906892     03/24/2014       12:33:00         POLICE DEPARTMENT
# 477    0890003162     05/31/2013       10:31:00         DOH MENTAL HEALTH
# 478    0890003180     05/29/2013       13:26:00         DOH MENTAL HEALTH
# 479    0890003190     05/29/2013       13:26:00         DOH MENTAL HEALTH
# 480    0890003272     05/21/2013       13:28:00         DOH MENTAL HEALTH
# 481    0890003281     05/21/2013       11:43:00         DOH/MENTAL HEALTH
# 482    0890003290     05/21/2013       11:43:00         DOH/MENTAL HEALTH
# 483    0890003300     05/21/2013       09:20:00         DOH MENTAL HEALTH
# 484    0890003209     05/29/2013       10:58:00         DOH MENTAL HEALTH
# 485    0183906901     03/24/2014       13:30:00         POLICE DEPARTMENT
# 486    0890003319     05/21/2013       09:20:00         DOH MENTAL HEALTH
# 487    0890003328     05/21/2013       09:20:00         DOH MENTAL HEALTH
# 488    0890003337     05/21/2013       09:20:00         DOH MENTAL HEALTH
# 489    0890003346     05/17/2013       11:19:00         DOH/MENTAL HEALTH
# 490    0890003355     05/17/2013       09:53:00         DOH/MENTAL HEALTH
# 491    0890003364     05/17/2013       09:53:00         DOH/MENTAL HEALTH
# 492    0890003400     05/15/2013       11:55:00         DOH MENTAL HEALTH
# 493    0890003410     05/15/2013       11:55:00         DOH MENTAL HEALTH
# 494    0890003429     05/08/2013       15:46:00         DOH MENTAL HEALTH
# 495    0890003465     05/07/2013       13:48:00         DOH/MENTAL HEALTH
# 496    0890003658     04/15/2013       14:52:00         DOH MENTAL HEALTH
# 497    0890003566     05/01/2013       11:39:00         DOH MENTAL HEALTH
# 498    0890003575     05/01/2013       11:39:00         DOH MENTAL HEALTH
# 499    0890003584     05/01/2013       09:01:00         DOH MENTAL HEALTH
#
#             Respondent Last Name Respondent First Name Balance Due  \
# 0                        ADERDOR                  SAID     $385.00
# 1                           RYAD                 MAGDY       $0.00
# 2           COMPUTIME INC PROFIT                   NaN       $0.00
# 3               509 CHAUNCEY LLC                   NaN       $0.00
# 4                            ALI         SHEHZAD ANWAR       $0.00
# 5                        BRITTON               BEVERLY       $0.00
# 6                           AMIN                GHANEM       $0.00
# 7                           TORO                GERMAN       $0.00
# 8               JOHN LUCY BLOZEN                   NaN       $0.00
# 9                           BAEZ             LETICIA A       $0.00
# 10                      BASHIRUL                 HOQUE       $0.00
# 11                      MOHAMMED               MHOUJEB       $0.00
# 12                         GUMUS                 YASAR       $0.00
# 13                        BHUIYA                    MD       $0.00
# 14                       ARGYROS            NIKOLAOS D       $0.00
# 15                       ARGYROS            NIKOLAOS D       $0.00
# 16                   SHAHABUDDIN               GOLAM M       $0.00
# 17                   SHAHABUDDIN               GOLAM M       $0.00
# 18                         MALIK            MUHAMMAD S       $0.00
# 19                   SHAHABUDDIN               GOLAM M       $0.00
# 20                   SHAHABUDDIN               GOLAM M       $0.00
# 21                         MALIK            MUHAMMAD S       $0.00
# 22                         MALIK            MUHAMMAD S       $0.00
# 23                    ALI ASHRAF              MOHAMMED       $0.00
# 24                    ALI ASHRAF              MOHAMMED       $0.00
# 25                        RAHMAN            MOHAMMED S    $-500.00
# 26                    ALI ASHRAF              MOHAMMED       $0.00
# 27                       KANDELL               AHMED H      $50.00
# 28            MOSTAFA ABDELHALIM               MOHAMED      $50.00
# 29                   KAMISIRIDIS            EFSTATHIOS       $0.00
# ..                           ...                   ...         ...
# 470  EMERALD 85-87 VERMILYEA LLC                   NaN    $1030.00
# 471                     OKBM INC                   NaN    $1030.00
# 472        MICHAEL BURKE III LLC                   NaN    $1000.00
# 473            WICK HOLDING CORP                   NaN       $0.00
# 474                      KEMPLER                 JACOB       $0.00
# 475                         EVAN                 JECOL    $1030.00
# 476                        HAMDY                 AYMAN      $50.00
# 477               ASHRAF HUSSIEN                   NaN    $1000.00
# 478           MATEO LUIS ALFREDO                   NaN    $1000.00
# 479           MATEO LUIS ALFREDO                   NaN    $1000.00
# 480               ELREFAEY ALI A                   NaN       $0.00
# 481             GONZALEZ MARITZA                   NaN         NaN
# 482             GONZALEZ MARITZA                   NaN         NaN
# 483          ANGEL RAMALES PEDRO                   NaN      $50.00
# 484                 POLANCO IRIS                   NaN       $0.00
# 485                        AYMAN           ABDELFALLAH       $0.00
# 486          ANGEL RAMALES PEDRO                   NaN     $600.00
# 487          ANGEL RAMALES PEDRO                   NaN     $770.00
# 488          ANGEL RAMALES PEDRO                   NaN     $770.00
# 489                        VERAS               YORAIMI         NaN
# 490                        VARAS               YORAIMI         NaN
# 491                        VERAS               YORAIMI         NaN
# 492            PIMENTEL-LARA S A                   NaN    $1000.00
# 493            PIMENTEL-LARA S A                   NaN    $1000.00
# 494                  LEON JOSE E                   NaN       $0.00
# 495                   SABERY ABU                   NaN         NaN
# 496     MAVROFORAKIS CONSTANTINE                   NaN       $0.00
# 497                  LLANOS OMAR                   NaN    $1000.00
# 498                  LLANOS OMAR                   NaN    $1000.00
# 499                   DE LA CRUZ                   EDY    $1000.00
#
#     Violation Location (Borough)  Violation Location (Block No.)  \
# 0                      MANHATTAN                             NaN
# 1                      MANHATTAN                             NaN
# 2                       BROOKLYN                          1992.0
# 3                       BROOKLYN                          1511.0
# 4                       BROOKLYN                          3187.0
# 5                       BROOKLYN                          3173.0
# 6                          BRONX                          3191.0
# 7                       BROOKLYN                          1515.0
# 8                       BROOKLYN                          2313.0
# 9                       BROOKLYN                          1847.0
# 10                        QUEENS                          1284.0
# 11                        QUEENS                             NaN
# 12                        QUEENS                          1320.0
# 13                        QUEENS                          1284.0
# 14                     MANHATTAN                             NaN
# 15                     MANHATTAN                             NaN
# 16                     MANHATTAN                             NaN
# 17                     MANHATTAN                             NaN
# 18                     MANHATTAN                          1130.0
# 19                     MANHATTAN                             NaN
# 20                     MANHATTAN                             NaN
# 21                     MANHATTAN                          1130.0
# 22                     MANHATTAN                          1130.0
# 23                     MANHATTAN                          1162.0
# 24                     MANHATTAN                          1162.0
# 25                     MANHATTAN                          1139.0
# 26                     MANHATTAN                          1162.0
# 27                     MANHATTAN                             NaN
# 28                     MANHATTAN                             NaN
# 29                     MANHATTAN                             NaN
# ..                           ...                             ...
# 470                    MANHATTAN                          2225.0
# 471                     BROOKLYN                          1773.0
# 472                    MANHATTAN                          1749.0
# 473                    MANHATTAN                          1838.0
# 474                     BROOKLYN                          5084.0
# 475                     BROOKLYN                          5208.0
# 476                    MANHATTAN                             NaN
# 477                        BRONX                          3673.0
# 478                        BRONX                          3102.0
# 479                        BRONX                          3102.0
# 480                        BRONX                          4835.0
# 481                        BRONX                          5117.0
# 482                        BRONX                          5117.0
# 483                        BRONX                          5112.0
# 484                        BRONX                          3126.0
# 485                    MANHATTAN                             NaN
# 486                        BRONX                          5112.0
# 487                        BRONX                          5112.0
# 488                        BRONX                          5112.0
# 489                        BRONX                             NaN
# 490                        BRONX                             NaN
# 491                        BRONX                             NaN
# 492                        BRONX                          2676.0
# 493                        BRONX                          2676.0
# 494                        BRONX                          3327.0
# 495                        BRONX                          3327.0
# 496                    MANHATTAN                           826.0
# 497                        BRONX                          2623.0
# 498                        BRONX                          2623.0
# 499                        BRONX                             NaN
#
#      Violation Location (Lot No.)             ...               \
# 0                             NaN             ...
# 1                             NaN             ...
# 2                            24.0             ...
# 3                            71.0             ...
# 4                            38.0             ...
# 5                            15.0             ...
# 6                            30.0             ...
# 7                            18.0             ...
# 8                            27.0             ...
# 9                            44.0             ...
# 10                         7501.0             ...
# 11                            NaN             ...
# 12                           27.0             ...
# 13                         7501.0             ...
# 14                            NaN             ...
# 15                            NaN             ...
# 16                            NaN             ...
# 17                            NaN             ...
# 18                            1.0             ...
# 19                            NaN             ...
# 20                            NaN             ...
# 21                            1.0             ...
# 22                            1.0             ...
# 23                           29.0             ...
# 24                           29.0             ...
# 25                         7503.0             ...
# 26                           29.0             ...
# 27                            NaN             ...
# 28                            NaN             ...
# 29                            NaN             ...
# ..                            ...             ...
# 470                          16.0             ...
# 471                          12.0             ...
# 472                         104.0             ...
# 473                          21.0             ...
# 474                          24.0             ...
# 475                          25.0             ...
# 476                           NaN             ...
# 477                           1.0             ...
# 478                          30.0             ...
# 479                          30.0             ...
# 480                          49.0             ...
# 481                          55.0             ...
# 482                          55.0             ...
# 483                          23.0             ...
# 484                           1.0             ...
# 485                           NaN             ...
# 486                          23.0             ...
# 487                          23.0             ...
# 488                          23.0             ...
# 489                           NaN             ...
# 490                           NaN             ...
# 491                           NaN             ...
# 492                          49.0             ...
# 493                          49.0             ...
# 494                           1.0             ...
# 495                         200.0             ...
# 496                          46.0             ...
# 497                          60.0             ...
# 498                          60.0             ...
# 499                           NaN             ...
#
#     Compliance Status Violation Description  Charge #1: Code  \
# 0         Penalty Due                   NaN             AH3G
# 1       All Terms Met                   NaN             AH3G
# 2       All Terms Met                   NaN             AH50
# 3       All Terms Met                   NaN             AH50
# 4       All Terms Met                   NaN             AH50
# 5       All Terms Met                   NaN             AH50
# 6       All Terms Met                   NaN             AH3I
# 7       All Terms Met                   NaN             AH50
# 8       All Terms Met                   NaN             AH50
# 9       All Terms Met                   NaN             AH50
# 10      All Terms Met                   NaN             AH3I
# 11      All Terms Met                   NaN             AH3G
# 12      All Terms Met                   NaN             AH3G
# 13      All Terms Met                   NaN             AH3I
# 14      All Terms Met                   NaN             AF18
# 15      All Terms Met                   NaN             AF18
# 16      All Terms Met                   NaN             AF05
# 17      All Terms Met                   NaN             AF18
# 18      All Terms Met                   NaN             AF13
# 19      All Terms Met                   NaN             AF18
# 20      All Terms Met                   NaN             AF18
# 21      All Terms Met                   NaN             AF16
# 22      All Terms Met                   NaN             AF21
# 23      All Terms Met                   NaN             AF13
# 24      All Terms Met                   NaN             AF18
# 25      All Terms Met                   NaN             AF16
# 26      All Terms Met                   NaN             AF16
# 27        Penalty Due                   NaN             AF05
# 28        Penalty Due                   NaN             AF19
# 29      All Terms Met                   NaN             AF18
# ..                ...                   ...              ...
# 470       Penalty Due                   NaN             AH3M
# 471       Penalty Due                   NaN             AH3M
# 472       Penalty Due                   NaN             AH3M
# 473     All Terms Met                   NaN             AH3K
# 474     All Terms Met                   NaN             AH3K
# 475       Penalty Due                   NaN             AH3K
# 476       Penalty Due                   NaN             AF14
# 477       Penalty Due                   NaN             AF02
# 478       Penalty Due                   NaN             AF01
# 479       Penalty Due                   NaN             AF02
# 480     All Terms Met                   NaN             AF16
# 481     All Terms Met                   NaN             AF02
# 482     All Terms Met                   NaN             AF01
# 483       Penalty Due                   NaN             AF16
# 484     All Terms Met                   NaN             AF02
# 485     All Terms Met                   NaN             AF18
# 486       Penalty Due                   NaN             AH1G
# 487       Penalty Due                   NaN             AH02
# 488       Penalty Due                   NaN             AH02
# 489     All Terms Met                   NaN             AF02
# 490     All Terms Met                   NaN             AF05
# 491     All Terms Met                   NaN             AF16
# 492       Penalty Due                   NaN             AF01
# 493       Penalty Due                   NaN             AF02
# 494     All Terms Met                   NaN             AF16
# 495     All Terms Met                   NaN             AH99
# 496     All Terms Met                   NaN             AF05
# 497       Penalty Due                   NaN             AF01
# 498       Penalty Due                   NaN             AF02
# 499       Penalty Due                   NaN             AF02
#
#     Charge #1: Code Section  \
# 0              H.C. 89.25 A
# 1              H.C. 89.25 A
# 2             H.C. 151.03 A
# 3             H.C. 151.03 A
# 4             H.C. 151.03 A
# 5             H.C. 151.03 A
# 6              H.C. 89.25 C
# 7             H.C. 151.03 A
# 8             H.C. 151.03 A
# 9             H.C. 151.03 A
# 10             H.C. 89.25 C
# 11             H.C. 89.25 A
# 12             H.C. 89.25 A
# 13             H.C. 89.25 C
# 14              AC 17-315 E
# 15              AC 17-315 E
# 16                   17-311
# 17              AC 17-315 E
# 18                 17-315 A
# 19              AC 17-315 E
# 20              AC 17-315 E
# 21                 17-315 C
# 22                 17-315 I
# 23                 17-315 A
# 24              AC 17-315 E
# 25                 17-315 C
# 26                 17-315 C
# 27                   17-311
# 28                 17-315 F
# 29              AC 17-315 E
# ..                      ...
# 470              NYCHC 3.09
# 471              NYCHC 3.09
# 472              NYCHC 3.09
# 473              NYCHC 3.05
# 474              NYCHC 3.05
# 475              NYCHC 3.05
# 476                17-315 B
# 477           A.C. 17-307 B
# 478           A.C. 17-307 A
# 479           A.C. 17-307 B
# 480                17-315 C
# 481          A.C. 17-307(B)
# 482          A.C. 17-307(A)
# 483                17-315 C
# 484           A.C. 17-307 B
# 485             AC 17-315 E
# 486              H.C. 81.31
# 487              H.C. 81.09
# 488              H.C. 81.09
# 489          A.C. 17-307(B)
# 490                  17-311
# 491               17-315(C)
# 492           A.C. 17-307 A
# 493           A.C. 17-307 B
# 494                17-315 C
# 495             HEALTH CODE
# 496                  17-311
# 497           A.C. 17-307 A
# 498           A.C. 17-307 B
# 499           A.C. 17-307 B
#
#                            Charge #1: Code Description  \
# 0          IMPROPER GARBAGE COLLECTION AND OR DISPOSAL
# 1          IMPROPER GARBAGE COLLECTION AND OR DISPOSAL
# 2                                      RAT INFESTATION
# 3                                      RAT INFESTATION
# 4                                      RAT INFESTATION
# 5                                      RAT INFESTATION
# 6    FAILURE TO PROPERLY REMOVE AND OR CLEAN DEBRIS...
# 7                                      RAT INFESTATION
# 8                                      RAT INFESTATION
# 9                                      RAT INFESTATION
# 10   FAILURE TO PROPERLY REMOVE AND OR CLEAN DEBRIS...
# 11         IMPROPER GARBAGE COLLECTION AND OR DISPOSAL
# 12         IMPROPER GARBAGE COLLECTION AND OR DISPOSAL
# 13   FAILURE TO PROPERLY REMOVE AND OR CLEAN DEBRIS...
# 14   VEND IN BUS STOP, NEXT TO HOSPITAL 10 FT OF DR...
# 15   VEND IN BUS STOP, NEXT TO HOSPITAL 10 FT OF DR...
# 16                FAIL TO DISPLAY LICENSE AND OR PLATE
# 17   VEND IN BUS STOP, NEXT TO HOSPITAL 10 FT OF DR...
# 18   VENDOR ON SIDEWALK LESS THAN 12FT., OR NOT AT ...
# 19   VEND IN BUS STOP, NEXT TO HOSPITAL 10 FT OF DR...
# 20   VEND IN BUS STOP, NEXT TO HOSPITAL 10 FT OF DR...
# 21   ITEMS NOT IN OR UNDER CART EXCEPT WASTE CONTAINER
# 22   VENDING WITHIN PARKS JURISDICTION WITHOUT COMM...
# 23   VENDOR ON SIDEWALK LESS THAN 12FT., OR NOT AT ...
# 24   VEND IN BUS STOP, NEXT TO HOSPITAL 10 FT OF DR...
# 25   ITEMS NOT IN OR UNDER CART EXCEPT WASTE CONTAINER
# 26   ITEMS NOT IN OR UNDER CART EXCEPT WASTE CONTAINER
# 27                FAIL TO DISPLAY LICENSE AND OR PLATE
# 28          VIOLATION OF PARKING RULES AND REGULATIONS
# 29   VEND IN BUS STOP, NEXT TO HOSPITAL 10 FT OF DR...
# ..                                                 ...
# 470             FAILING TO ABATE OR REMEDIATE NUISANCE
# 471             FAILING TO ABATE OR REMEDIATE NUISANCE
# 472             FAILING TO ABATE OR REMEDIATE NUISANCE
# 473  FAILING TO COMPLY WITH DEPT, BOARD OF HEALTH, ...
# 474  FAILING TO COMPLY WITH DEPT, BOARD OF HEALTH, ...
# 475  FAILING TO COMPLY WITH DEPT, BOARD OF HEALTH, ...
# 476          CART TOUCHING OR LEANING AGAINST BUILDING
# 477                       UNPERMITTED MOBILE FOOD UNIT
# 478                      UNLICENSED MOBILE FOOD VENDOR
# 479                       UNPERMITTED MOBILE FOOD UNIT
# 480  ITEMS NOT IN OR UNDER CART EXCEPT WASTE CONTAINER
# 481                       UNPERMITTED MOBILE FOOD UNIT
# 482                      UNLICENSED MOBILE FOOD VENDOR
# 483  ITEMS NOT IN OR UNDER CART EXCEPT WASTE CONTAINER
# 484                       UNPERMITTED MOBILE FOOD UNIT
# 485  VEND IN BUS STOP, NEXT TO HOSPITAL 10 FT OF DR...
# 486         EQUIPMENT NOT CLEAN; IMPROPERLY MAINTAINED
# 487  POTENTIALLY HAZARDOUS FOODS AT IMPROPER TEMPER...
# 488  POTENTIALLY HAZARDOUS FOODS AT IMPROPER TEMPER...
# 489                       UNPERMITTED MOBILE FOOD UNIT
# 490               FAIL TO DISPLAY LICENSE AND/OR PLATE
# 491  ITEMS NOT IN OR UNDER CART (EXCEPT WASTE CONTA...
# 492                      UNLICENSED MOBILE FOOD VENDOR
# 493                       UNPERMITTED MOBILE FOOD UNIT
# 494  ITEMS NOT IN OR UNDER CART EXCEPT WASTE CONTAINER
# 495                        HEALTH CODE PROVISION-MISC.
# 496               FAIL TO DISPLAY LICENSE AND OR PLATE
# 497                      UNLICENSED MOBILE FOOD VENDOR
# 498                       UNPERMITTED MOBILE FOOD UNIT
# 499                       UNPERMITTED MOBILE FOOD UNIT
#
#     Charge #1: Infraction Amount Charge #2: Code Charge #2: Code Section  \
# 0                        $385.00             NaN                     NaN
# 1                        $385.00             NaN                     NaN
# 2                        $200.00             NaN                     NaN
# 3                        $200.00             NaN                     NaN
# 4                        $200.00             NaN                     NaN
# 5                        $200.00             NaN                     NaN
# 6                        $385.00             NaN                     NaN
# 7                        $200.00             NaN                     NaN
# 8                        $200.00             NaN                     NaN
# 9                        $200.00             NaN                     NaN
# 10                       $385.00             NaN                     NaN
# 11                       $385.00             NaN                     NaN
# 12                       $385.00             NaN                     NaN
# 13                       $385.00             NaN                     NaN
# 14                       $100.00             NaN                     NaN
# 15                       $100.00             NaN                     NaN
# 16                       $100.00             NaN                     NaN
# 17                       $100.00             NaN                     NaN
# 18                       $100.00             NaN                     NaN
# 19                       $100.00             NaN                     NaN
# 20                       $100.00             NaN                     NaN
# 21                       $100.00             NaN                     NaN
# 22                       $100.00             NaN                     NaN
# 23                       $100.00             NaN                     NaN
# 24                       $100.00             NaN                     NaN
# 25                       $100.00             NaN                     NaN
# 26                       $100.00             NaN                     NaN
# 27                       $100.00             NaN                     NaN
# 28                       $100.00             NaN                     NaN
# 29                       $100.00             NaN                     NaN
# ..                           ...             ...                     ...
# 470                     $1000.00             NaN                     NaN
# 471                     $1000.00             NaN                     NaN
# 472                     $1000.00             NaN                     NaN
# 473                     $1000.00             NaN                     NaN
# 474                     $1000.00             NaN                     NaN
# 475                     $1000.00             NaN                     NaN
# 476                      $100.00             NaN                     NaN
# 477                     $1000.00             NaN                     NaN
# 478                     $1000.00             NaN                     NaN
# 479                     $1000.00             NaN                     NaN
# 480                      $100.00             NaN                     NaN
# 481                     $1000.00             NaN                     NaN
# 482                     $1000.00             NaN                     NaN
# 483                      $100.00             NaN                     NaN
# 484                     $1000.00             NaN                     NaN
# 485                      $100.00             NaN                     NaN
# 486                      $300.00             NaN                     NaN
# 487                      $385.00             NaN                     NaN
# 488                      $385.00             NaN                     NaN
# 489                     $1000.00             NaN                     NaN
# 490                          NaN             NaN                     NaN
# 491                          NaN             NaN                     NaN
# 492                     $1000.00             NaN                     NaN
# 493                     $1000.00             NaN                     NaN
# 494                      $100.00             NaN                     NaN
# 495                      $200.00             NaN                     NaN
# 496                      $100.00             NaN                     NaN
# 497                     $1000.00             NaN                     NaN
# 498                     $1000.00             NaN                     NaN
# 499                     $1000.00             NaN                     NaN
#
#     Charge #2: Code Description Charge #2: Infraction Amount
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
# 5                           NaN                          NaN
# 6                           NaN                          NaN
# 7                           NaN                          NaN
# 8                           NaN                          NaN
# 9                           NaN                          NaN
# 10                          NaN                          NaN
# 11                          NaN                          NaN
# 12                          NaN                          NaN
# 13                          NaN                          NaN
# 14                          NaN                          NaN
# 15                          NaN                          NaN
# 16                          NaN                          NaN
# 17                          NaN                          NaN
# 18                          NaN                          NaN
# 19                          NaN                          NaN
# 20                          NaN                          NaN
# 21                          NaN                          NaN
# 22                          NaN                          NaN
# 23                          NaN                          NaN
# 24                          NaN                          NaN
# 25                          NaN                          NaN
# 26                          NaN                          NaN
# 27                          NaN                          NaN
# 28                          NaN                          NaN
# 29                          NaN                          NaN
# ..                          ...                          ...
# 470                         NaN                          NaN
# 471                         NaN                          NaN
# 472                         NaN                          NaN
# 473                         NaN                          NaN
# 474                         NaN                          NaN
# 475                         NaN                          NaN
# 476                         NaN                          NaN
# 477                         NaN                          NaN
# 478                         NaN                          NaN
# 479                         NaN                          NaN
# 480                         NaN                          NaN
# 481                         NaN                          NaN
# 482                         NaN                          NaN
# 483                         NaN                          NaN
# 484                         NaN                          NaN
# 485                         NaN                          NaN
# 486                         NaN                          NaN
# 487                         NaN                          NaN
# 488                         NaN                          NaN
# 489                         NaN                          NaN
# 490                         NaN                          NaN
# 491                         NaN                          NaN
# 492                         NaN                          NaN
# 493                         NaN                          NaN
# 494                         NaN                          NaN
# 495                         NaN                          NaN
# 496                         NaN                          NaN
# 497                         NaN                          NaN
# 498                         NaN                          NaN
# 499                         NaN                          NaN
#
# [500 rows x 46 columns]

# %%
reduced_data2 = data2[["Violation Date","Charge #1: Infraction Amount"]]
reduced_data2.head()
# Out:
#   Violation Date Charge #1: Infraction Amount
# 0     12/22/2012                      $385.00
# 1     07/09/2012                      $385.00
# 2     05/10/2007                      $200.00
# 3     07/11/2007                      $200.00
# 4     02/18/2009                      $200.00

# %%
reduced_data2.columns=["Date","Charge"]
reduced_data2.head()
# Out:
#          Date   Charge
# 0  12/22/2012  $385.00
# 1  07/09/2012  $385.00
# 2  05/10/2007  $200.00
# 3  07/11/2007  $200.00
# 4  02/18/2009  $200.00

# %%
reduced_data2["Charge"] = reduced_data2["Charge"].replace('[$]','',regex =  True).astype(float)
reduced_data2.head()
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#          Date  Charge
# 0  12/22/2012   385.0
# 1  07/09/2012   385.0
# 2  05/10/2007   200.0
# 3  07/11/2007   200.0
# 4  02/18/2009   200.0

# %%
reduced_data2.dtypes
# Out:
# Date       object
# Charge    float64
# dtype: object

# %%
reduced_data2["Date"] = pd.to_datetime(reduced_data2["Date"],format="%m/%d/%Y")
type(reduced_data2["Date"][0])
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# pandas.tslib.Timestamp

# %%
plt.figure(figsize=(15,15))
plt.title("Violation Charge",fontsize=16)
plt.scatter(reduced_data2["Date"].tolist(), reduced_data2["Charge"])
plt.xlabel("Date")
plt.ylabel("Charge")
plt.show()
