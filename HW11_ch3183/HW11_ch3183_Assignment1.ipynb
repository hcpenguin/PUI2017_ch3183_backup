# %% [markdown]
# # Time series clustering exercise

# %% [markdown]
# # Data

# %% [markdown]
# Download the census bureau business data for all years 1993-2014. You can investigate using the API (I have not done it with the census bureau). I did is as you see below

# %%
import pandas as pd
import zipfile
import glob
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist, pdist
import matplotlib.pyplot as plt
import seaborn
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering
import os
import urllib.request as urllib
import geopandas as gpd

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Business Data

# %%
#these commands can be run on the shell and get the data with the command wget
#the cell needs to be run only once
# !for ((y=93; y<=99; y+=1)); do wget \
https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp$y\totals.zip; done

# !for ((y=0; y<=1; y+=1)); do wget \
https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp0$y\totals.zip; done

# !for ((y=2; y<=9; y+=1)); do wget \
https://www2.census.gov/econ200$y\/CBP_CSV/zbp0$y\totals.zip; done

# !for ((y=10; y<=14; y+=1)); do wget \
https://www2.census.gov/econ20$y\/CBP_CSV/zbp$y\totals.zip; done
# Out:
# --2017-12-11 10:48:15--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp93totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2017-12-11 10:48:15 ERROR 404: Not Found.
#
# --2017-12-11 10:48:15--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp94totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 611524 (597K) [application/zip]
# Saving to: 'zbp94totals.zip'
#
# zbp94totals.zip     100%[===================>] 597.19K  2.93MB/s    in 0.2s
#
# 2017-12-11 10:48:16 (2.93 MB/s) - 'zbp94totals.zip' saved [611524/611524]
#
# --2017-12-11 10:48:16--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp95totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 625328 (611K) [application/zip]
# Saving to: 'zbp95totals.zip'
#
# zbp95totals.zip     100%[===================>] 610.67K  2.25MB/s    in 0.3s
#
# 2017-12-11 10:48:16 (2.25 MB/s) - 'zbp95totals.zip' saved [625328/625328]
#
# --2017-12-11 10:48:16--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp96totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 632625 (618K) [application/zip]
# Saving to: 'zbp96totals.zip'
#
# zbp96totals.zip     100%[===================>] 617.80K  3.44MB/s    in 0.2s
#
# 2017-12-11 10:48:16 (3.44 MB/s) - 'zbp96totals.zip' saved [632625/632625]
#
# --2017-12-11 10:48:16--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp97totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 629368 (615K) [application/zip]
# Saving to: 'zbp97totals.zip'
#
# zbp97totals.zip     100%[===================>] 614.62K  --.-KB/s    in 0.1s
#
# 2017-12-11 10:48:16 (5.14 MB/s) - 'zbp97totals.zip' saved [629368/629368]
#
# --2017-12-11 10:48:16--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp98totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 617784 (603K) [application/zip]
# Saving to: 'zbp98totals.zip'
#
# zbp98totals.zip     100%[===================>] 603.30K  1.31MB/s    in 0.5s
#
# 2017-12-11 10:48:17 (1.31 MB/s) - 'zbp98totals.zip' saved [617784/617784]
#
# --2017-12-11 10:48:17--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp99totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 625814 (611K) [application/zip]
# Saving to: 'zbp99totals.zip'
#
# zbp99totals.zip     100%[===================>] 611.15K  --.-KB/s    in 0.09s
#
# 2017-12-11 10:48:17 (6.80 MB/s) - 'zbp99totals.zip' saved [625814/625814]
#
# --2017-12-11 10:48:17--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp00totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 628434 (614K) [application/zip]
# Saving to: 'zbp00totals.zip'
#
# zbp00totals.zip     100%[===================>] 613.71K  --.-KB/s    in 0.09s
#
# 2017-12-11 10:48:17 (6.38 MB/s) - 'zbp00totals.zip' saved [628434/628434]
#
# --2017-12-11 10:48:17--  https://www2.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp01totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 628815 (614K) [application/zip]
# Saving to: 'zbp01totals.zip'
#
# zbp01totals.zip     100%[===================>] 614.08K  3.46MB/s    in 0.2s
#
# 2017-12-11 10:48:18 (3.46 MB/s) - 'zbp01totals.zip' saved [628815/628815]
#
# --2017-12-11 10:48:18--  https://www2.census.gov/econ2002/CBP_CSV/zbp02totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 620754 (606K) [application/zip]
# Saving to: 'zbp02totals.zip'
#
# zbp02totals.zip     100%[===================>] 606.21K  --.-KB/s    in 0.1s
#
# 2017-12-11 10:48:18 (5.14 MB/s) - 'zbp02totals.zip' saved [620754/620754]
#
# --2017-12-11 10:48:18--  https://www2.census.gov/econ2003/CBP_CSV/zbp03totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 622790 (608K) [application/zip]
# Saving to: 'zbp03totals.zip'
#
# zbp03totals.zip     100%[===================>] 608.19K  --.-KB/s    in 0.1s
#
# 2017-12-11 10:48:18 (4.37 MB/s) - 'zbp03totals.zip' saved [622790/622790]
#
# --2017-12-11 10:48:18--  https://www2.census.gov/econ2004/CBP_CSV/zbp04totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 625803 (611K) [application/zip]
# Saving to: 'zbp04totals.zip'
#
# zbp04totals.zip     100%[===================>] 611.14K  --.-KB/s    in 0.1s
#
# 2017-12-11 10:48:18 (4.12 MB/s) - 'zbp04totals.zip' saved [625803/625803]
#
# --2017-12-11 10:48:18--  https://www2.census.gov/econ2005/CBP_CSV/zbp05totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 627583 (613K) [application/zip]
# Saving to: 'zbp05totals.zip'
#
# zbp05totals.zip     100%[===================>] 612.87K  --.-KB/s    in 0.09s
#
# 2017-12-11 10:48:18 (6.74 MB/s) - 'zbp05totals.zip' saved [627583/627583]
#
# --2017-12-11 10:48:18--  https://www2.census.gov/econ2006/CBP_CSV/zbp06totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 629107 (614K) [application/zip]
# Saving to: 'zbp06totals.zip'
#
# zbp06totals.zip     100%[===================>] 614.36K  --.-KB/s    in 0.1s
#
# 2017-12-11 10:48:19 (4.46 MB/s) - 'zbp06totals.zip' saved [629107/629107]
#
# --2017-12-11 10:48:19--  https://www2.census.gov/econ2007/CBP_CSV/zbp07totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 667754 (652K) [application/zip]
# Saving to: 'zbp07totals.zip'
#
# zbp07totals.zip     100%[===================>] 652.10K  --.-KB/s    in 0.07s
#
# 2017-12-11 10:48:19 (8.83 MB/s) - 'zbp07totals.zip' saved [667754/667754]
#
# --2017-12-11 10:48:19--  https://www2.census.gov/econ2008/CBP_CSV/zbp08totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 663242 (648K) [application/zip]
# Saving to: 'zbp08totals.zip'
#
# zbp08totals.zip     100%[===================>] 647.70K  --.-KB/s    in 0.08s
#
# 2017-12-11 10:48:19 (8.16 MB/s) - 'zbp08totals.zip' saved [663242/663242]
#
# --2017-12-11 10:48:19--  https://www2.census.gov/econ2009/CBP_CSV/zbp09totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 660109 (645K) [application/zip]
# Saving to: 'zbp09totals.zip'
#
# zbp09totals.zip     100%[===================>] 644.64K  --.-KB/s    in 0.07s
#
# 2017-12-11 10:48:19 (8.81 MB/s) - 'zbp09totals.zip' saved [660109/660109]
# --2017-12-11 10:48:19--  https://www2.census.gov/econ2010/CBP_CSV/zbp10totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 797534 (779K) [application/zip]
# Saving to: 'zbp10totals.zip'
#
# zbp10totals.zip     100%[===================>] 778.84K  --.-KB/s    in 0.09s
#
# 2017-12-11 10:48:19 (8.02 MB/s) - 'zbp10totals.zip' saved [797534/797534]
#
# --2017-12-11 10:48:19--  https://www2.census.gov/econ2011/CBP_CSV/zbp11totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 795390 (777K) [application/zip]
# Saving to: 'zbp11totals.zip'
#
# zbp11totals.zip     100%[===================>] 776.75K  --.-KB/s    in 0.1s
#
# 2017-12-11 10:48:19 (7.51 MB/s) - 'zbp11totals.zip' saved [795390/795390]
#
# --2017-12-11 10:48:19--  https://www2.census.gov/econ2012/CBP_CSV/zbp12totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 733541 (716K) [application/zip]
# Saving to: 'zbp12totals.zip'
#
# zbp12totals.zip     100%[===================>] 716.35K  3.92MB/s    in 0.2s
#
# 2017-12-11 10:48:20 (3.92 MB/s) - 'zbp12totals.zip' saved [733541/733541]
#
# --2017-12-11 10:48:20--  https://www2.census.gov/econ2013/CBP_CSV/zbp13totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 733605 (716K) [application/zip]
# Saving to: 'zbp13totals.zip'
#
# zbp13totals.zip     100%[===================>] 716.41K  3.67MB/s    in 0.2s
#
# 2017-12-11 10:48:20 (3.67 MB/s) - 'zbp13totals.zip' saved [733605/733605]
#
# --2017-12-11 10:48:20--  https://www2.census.gov/econ2014/CBP_CSV/zbp14totals.zip
# Resolving www2.census.gov... 104.106.248.146, 2600:141b:13:1a4::208c
# Connecting to www2.census.gov|104.106.248.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 733763 (717K) [application/zip]
# Saving to: 'zbp14totals.zip'
#
# zbp14totals.zip     100%[===================>] 716.57K  --.-KB/s    in 0.09s
#
# 2017-12-11 10:48:20 (7.47 MB/s) - 'zbp14totals.zip' saved [733763/733763]

# %%
#get all data file names
allfilezip = glob.glob("*.zip")
allfilezip
# Out:
# ['zbp00totals.zip',
#  'zbp01totals.zip',
#  'zbp02totals.zip',
#  'zbp03totals.zip',
#  'zbp04totals.zip',
#  'zbp05totals.zip',
#  'zbp06totals.zip',
#  'zbp07totals.zip',
#  'zbp08totals.zip',
#  'zbp09totals.zip',
#  'zbp10totals.zip',
#  'zbp11totals.zip',
#  'zbp12totals.zip',
#  'zbp13totals.zip',
#  'zbp14totals.zip',
#  'zbp94totals.zip',
#  'zbp95totals.zip',
#  'zbp96totals.zip',
#  'zbp97totals.zip',
#  'zbp98totals.zip',
#  'zbp99totals.zip']

# %%
#move all download zipdata to PUIdata folder
for i in allfilezip:
    os.system('mv ' + i + ' $PUIDATA')

# %%
#get all unzipped data file names
os.chdir(os.getenv('PUIDATA'))
allfile = glob.glob("zbp*.zip")

# %%
allfile
# Out:
# ['zbp00totals.zip',
#  'zbp01totals.zip',
#  'zbp02totals.zip',
#  'zbp03totals.zip',
#  'zbp04totals.zip',
#  'zbp05totals.zip',
#  'zbp06totals.zip',
#  'zbp07totals.zip',
#  'zbp08totals.zip',
#  'zbp09totals.zip',
#  'zbp10totals.zip',
#  'zbp11totals.zip',
#  'zbp12totals.zip',
#  'zbp13totals.zip',
#  'zbp14totals.zip',
#  'zbp94totals.zip',
#  'zbp95totals.zip',
#  'zbp96totals.zip',
#  'zbp97totals.zip',
#  'zbp98totals.zip',
#  'zbp99totals.zip']

# %%
#concate all census files into dataframe
def func_(f):
    zf = zipfile.ZipFile(f)
    temp = pd.read_csv(zf.open(f.replace('.zip','.txt')))
    temp["Year"] = f[3:5]
    return temp
df = pd.concat(func_(f) for f in allfile)
df.head()
# Out:
#          AP     EMP EMPFLAG    EST            NAME      QP1 Year     ZIP  ap  \
# 0       0.0     0.0       A    1.0  HOLTSVILLE, NY      0.0   00   501.0 NaN
# 1  259661.0  8042.0     NaN  493.0      AGAWAM, MA  59833.0   00  1001.0 NaN
# 2  169658.0  6547.0     NaN  563.0     AMHERST, MA  36719.0   00  1002.0 NaN
# 3    2482.0    82.0     NaN   13.0     AMHERST, MA    308.0   00  1003.0 NaN
# 4    5826.0   717.0     NaN   48.0     AMHERST, MA   2049.0   00  1004.0 NaN
#
#   ap_nf ... cty_name emp  emp_nf empflag est  name qp1  qp1_nf stabbr zip
# 0   NaN ...      NaN NaN     NaN     NaN NaN   NaN NaN     NaN    NaN NaN
# 1   NaN ...      NaN NaN     NaN     NaN NaN   NaN NaN     NaN    NaN NaN
# 2   NaN ...      NaN NaN     NaN     NaN NaN   NaN NaN     NaN    NaN NaN
# 3   NaN ...      NaN NaN     NaN     NaN NaN   NaN NaN     NaN    NaN NaN
# 4   NaN ...      NaN NaN     NaN     NaN NaN   NaN NaN     NaN    NaN NaN
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (828791, 21)

# %% [markdown]
#  Download the NYC zipcodes shapefile. One of many ways in which you can get the zipcodes shapefile for NYC
#  https://data.cityofnewyork.us/download/i8iw-xf4u/application%2Fzip

# %% [markdown]
# # zip shape file

# %%
#download zip shapefile
url = 'https://data.cityofnewyork.us/download/i8iw-xf4u/application/zip'
urllib.urlretrieve(url, 'NYCZIP.zip')
os.system('unzip NYCZIP.zip -d ' + os.getenv('PUIDATA') + '/NYCZIP')
# Out:
# 256

# %%
shpfile = glob.glob((os.getenv('PUIDATA') + '/NYCZIP/' + '*.shp'))

# %%
zipshp = gpd.GeoDataFrame.from_file(shpfile[0])
print(zipshp.crs)
zipshp.head()
# Out:
# {'proj': 'lcc', 'lat_1': 40.66666666666666, 'lat_2': 41.03333333333333, 'lat_0': 40.16666666666666, 'lon_0': -74, 'x_0': 300000, 'y_0': 0, 'datum': 'NAD83', 'units': 'us-ft', 'no_defs': True}
#   ZIPCODE BLDGZIP   PO_NAME  POPULATION          AREA STATE  COUNTY ST_FIPS  \
# 0   11436       0   Jamaica     18681.0  2.269930e+07    NY  Queens      36
# 1   11213       0  Brooklyn     62426.0  2.963100e+07    NY   Kings      36
# 2   11212       0  Brooklyn     83866.0  4.197210e+07    NY   Kings      36
# 3   11225       0  Brooklyn     56527.0  2.369863e+07    NY   Kings      36
# 4   11218       0  Brooklyn     72280.0  3.686880e+07    NY   Kings      36
#
#   CTY_FIPS                   URL  SHAPE_AREA  SHAPE_LEN  \
# 0      081  http://www.usps.com/         0.0        0.0
# 1      047  http://www.usps.com/         0.0        0.0
# 2      047  http://www.usps.com/         0.0        0.0
# 3      047  http://www.usps.com/         0.0        0.0
# 4      047  http://www.usps.com/         0.0        0.0
#
#                                             geometry
# 0  POLYGON ((1038098.251871482 188138.3800067157,...
# 1  POLYGON ((1001613.712964058 186926.4395172149,...
# 2  POLYGON ((1011174.275535807 183696.33770971, 1...
# 3  POLYGON ((995908.3654508889 183617.6128015518,...
# 4  POLYGON ((991997.1134308875 176307.4958601296,...

# %% [markdown]
# # Data cleaning

# %% [markdown]
# you may need to clean your data: for some NYC zip codes there may be no info
# sanity check: you should have 20 (N_timestamps) datapoints per time series and about 250 zipcodes (Nzipcodes)
#
#
# IMPORTANT: we talked about the importance of "whitening" your data.
# Whitenings decorrelates the data: it makes the features independent so that the data covariance matrix is the identity matrix.
# Whitening your data in time series analysis is in most cases **wrong**: you are modifying your time behaviour. This is because of the strong correlation between features (two consecutive time stamps for the same observation, the same zip code here, are strongly correlated). Here instead you want to standardize your time series: subtract the mean and divide each time series (separately) by its standard deviation. As a sanity check (if you use skitlearn Kmeans or skitlearns kmeans2): you want your data array to be shaped Nzipcodes x Ntimestamps
#
# mydata.shape should be (Nzipcodes, Ntimestamps)
#
# mydata[i].std() shoould be 1 for all i in range(len(Nzipcodes))
#
# mydata[i].mean() should be ~0 for all i in range(len(Nzipcodes))

# %% [markdown]
# ## TASKS:
#
#     1. get and prep your data.
#     2. cluster the NUMBER OF ESTABLISHMENTS time series with K-means in **a few** clusters (as discussed there is no real good, sound way to decide what a good number is here. try a few options, keeping in mind a few is more than a couple, but i recommand you stay within the single digit numbers)
#     3. plot the cluster centers (if you used K means those are the means of the clusters). you can plot for example the cluster centers overlayed on each time series (using the alpha channel to control the opacity in the plot may be helpful here).
#     4. Use another clustering algorithm (of your choice)
#     5. overlay your data on a NYC map: you can use shapefiles for the zip codes and different colors for different clusters
#     6. Compare the results of the 2 algorithms
#     7. attempt an interpretation. this is dangerous ground: clustering is an exploratory tool so you do not want to jump to conclusions because you see some clusters! but seeing structure in your data can inform your next moves as an investigator.

# %%
#find all zipcode match records
df = df[df["ZIP"].isin(zipshp["ZIPCODE"].astype(float)) | df["zip"].isin(zipshp["ZIPCODE"].astype(float))]
df.head()
# Out:
#              AP       EMP EMPFLAG     EST          NAME        QP1 Year  \
# 3010  5568152.0  124661.0     NaN  7317.0  NEW YORK, NY  1608935.0   00
# 3011   386460.0   19185.0     NaN  2277.0  NEW YORK, NY    91736.0   00
# 3012  3055233.0   66250.0     NaN  3683.0  NEW YORK, NY   688955.0   00
# 3013  7022508.0   51582.0     NaN  1294.0  NEW YORK, NY  2331796.0   00
# 3014  3771552.0   38640.0     NaN  1287.0  NEW YORK, NY  1247362.0   00
#
#           ZIP  ap ap_nf ... cty_name emp  emp_nf empflag est  name qp1  \
# 3010  10001.0 NaN   NaN ...      NaN NaN     NaN     NaN NaN   NaN NaN
# 3011  10002.0 NaN   NaN ...      NaN NaN     NaN     NaN NaN   NaN NaN
# 3012  10003.0 NaN   NaN ...      NaN NaN     NaN     NaN NaN   NaN NaN
# 3013  10004.0 NaN   NaN ...      NaN NaN     NaN     NaN NaN   NaN NaN
# 3014  10005.0 NaN   NaN ...      NaN NaN     NaN     NaN NaN   NaN NaN
#
#       qp1_nf stabbr zip
# 3010     NaN    NaN NaN
# 3011     NaN    NaN NaN
# 3012     NaN    NaN NaN
# 3013     NaN    NaN NaN
# 3014     NaN    NaN NaN
#
# [5 rows x 21 columns]

# %%
#convert year format
df.Year = pd.to_datetime(df.Year.astype('str'), format="%y").dt.year
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#           AP       EMP EMPFLAG     EST          NAME        QP1  Year  \
# 0  5568152.0  124661.0     NaN  7317.0  NEW YORK, NY  1608935.0  2000
# 1   386460.0   19185.0     NaN  2277.0  NEW YORK, NY    91736.0  2000
# 2  3055233.0   66250.0     NaN  3683.0  NEW YORK, NY   688955.0  2000
# 3  7022508.0   51582.0     NaN  1294.0  NEW YORK, NY  2331796.0  2000
# 4  3771552.0   38640.0     NaN  1287.0  NEW YORK, NY  1247362.0  2000
#
#        ZIP  ap ap_nf ... cty_name emp  emp_nf empflag est  name qp1  qp1_nf  \
# 0  10001.0 NaN   NaN ...      NaN NaN     NaN     NaN NaN   NaN NaN     NaN
# 1  10002.0 NaN   NaN ...      NaN NaN     NaN     NaN NaN   NaN NaN     NaN
# 2  10003.0 NaN   NaN ...      NaN NaN     NaN     NaN NaN   NaN NaN     NaN
# 3  10004.0 NaN   NaN ...      NaN NaN     NaN     NaN NaN   NaN NaN     NaN
# 4  10005.0 NaN   NaN ...      NaN NaN     NaN     NaN NaN   NaN NaN     NaN
#
#   stabbr zip
# 0    NaN NaN
# 1    NaN NaN
# 2    NaN NaN
# 3    NaN NaN
# 4    NaN NaN
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (5019, 21)

# %%
#union records format and filter out time info&zipcode
df_union = pd.concat([df[["EST", "ZIP", "Year"]].dropna().rename(columns={"EST":"est", "ZIP":"zip"}), 
                      df[["est", "zip", "Year"]].dropna()])
df_union.head()
# Out:
#       est      zip  Year
# 0  7317.0  10001.0  2000
# 1  2277.0  10002.0  2000
# 2  3683.0  10003.0  2000
# 3  1294.0  10004.0  2000
# 4  1287.0  10005.0  2000

# %%
df_union.shape
# Out:
# (5019, 3)

# %%
#pivot info into zip/year
df_pivot = df_union.pivot(index="zip", columns="Year", values="est")

# %%
#whiting
df_pivot_std = df_pivot.apply(lambda x: (x - x.mean())/x.std(), axis=1)
df_pivot_std.fillna(0, inplace=True)

# %%
df_pivot_std.shape
# Out:
# (245, 21)

# %%
KMeanCluster = KMeans(n_clusters=5, random_state=2017).fit(df_pivot_std)

# %%
cmap = plt.cm.prism(np.linspace(0,1,5))
plt.figure(figsize=(10,8))
for i in range(len(df_pivot_std)):
    c = KMeanCluster.labels_[i]
    plt.plot(range(1994,2015), df_pivot_std.iloc[i,:], color=cmap[c][:3])
#for i in range(len(KMeanCluster.cluster_centers_)):
#    plt.plot(range(1994,2015), KMeanCluster.cluster_centers_[i], color="black", linewidth=3)
plt.title("Business Establishment")
plt.ylabel("standardized establishment")
plt.xlabel("year")
plt.xlim(1994,2014)
# Out:
# (1994, 2014)

# %% [markdown]
# Fig.1 Plot all business together

# %%
#plot the each cluster separately
plt.figure(figsize=(15, 25))

for M in range(0,5):
    plt.subplot(510+M+1)
    
    for i in range(len(df_pivot_std)):
        if(KMeanCluster.labels_[i]==M):
            plt.plot(range(1994,2015), df_pivot_std.iloc[i,:], color=cmap[c][:3])
        
    plt.plot(range(1994,2015), KMeanCluster.cluster_centers_[M], color="black", linewidth=10)
    plt.title("Business Establishment")
    plt.ylabel("standardized establishment")
    plt.xlabel("year")
    plt.xlim(1994,2014)

# %% [markdown]
# Fig.2 Plot each cluster in time series and its center line

# %%
Z = linkage(df_pivot_std.iloc[:,:].values, 'ward')

# %%
from scipy.cluster.hierarchy import set_link_color_palette
set_link_color_palette(['black'])

# %%
plt.figure(figsize=(20, 500))
plt.title('Hierarchical Clustering Dendrogram', fontsize=50)
dendrogram(
    Z,
    color_threshold=np.inf,
    orientation="left",
    labels = df_pivot_std.iloc[:,:].index.values,
    leaf_font_size=20.,  # font size for the x axis labels
)
plt.show()

# %% [markdown]
# Fig.3 Plot Hierarchy Cluster Result

# %%
AC = AgglomerativeClustering(n_clusters=5, linkage="ward").fit(df_pivot_std.iloc[:,:21])

# %%
KMdf = pd.DataFrame({"zip":df_pivot_std.index.values, "label":KMeanCluster.labels_})
ACdf = pd.DataFrame({"zip":df_pivot_std.index.values, "label":AC.labels_})

# %%
zipshp.rename(columns={"ZIPCODE":"zip"}, inplace=True)

# %%
zipshp["zip"] = pd.to_numeric(zipshp["zip"])

# %%
zipdf = zipshp.merge(KMdf, on="zip").merge(ACdf, on="zip")

# %%
zipdf.head()
# Out:
#      zip BLDGZIP   PO_NAME  POPULATION          AREA STATE  COUNTY ST_FIPS  \
# 0  11436       0   Jamaica     18681.0  2.269930e+07    NY  Queens      36
# 1  11213       0  Brooklyn     62426.0  2.963100e+07    NY   Kings      36
# 2  11212       0  Brooklyn     83866.0  4.197210e+07    NY   Kings      36
# 3  11225       0  Brooklyn     56527.0  2.369863e+07    NY   Kings      36
# 4  11218       0  Brooklyn     72280.0  3.686880e+07    NY   Kings      36
#
#   CTY_FIPS                   URL  SHAPE_AREA  SHAPE_LEN  \
# 0      081  http://www.usps.com/         0.0        0.0
# 1      047  http://www.usps.com/         0.0        0.0
# 2      047  http://www.usps.com/         0.0        0.0
# 3      047  http://www.usps.com/         0.0        0.0
# 4      047  http://www.usps.com/         0.0        0.0
#
#                                             geometry  label_x  label_y
# 0  POLYGON ((1038098.251871482 188138.3800067157,...        0        1
# 1  POLYGON ((1001613.712964058 186926.4395172149,...        0        1
# 2  POLYGON ((1011174.275535807 183696.33770971, 1...        0        1
# 3  POLYGON ((995908.3654508889 183617.6128015518,...        0        1
# 4  POLYGON ((991997.1134308875 176307.4958601296,...        0        1

# %%
f, ax = plt.subplots(figsize=(10,10))
zipdf.plot(column="label_x", cmap="plasma", figsize=(15,10), ax=ax)
ax.set_title("KMeans cluster on the NYC Business Establishment")
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
ax.set_axis_bgcolor('white')
# Out:
# /Users/cihe/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.

# %% [markdown]
# Fig.4 Plot the kmean result on NYC geomap

# %%
f, ax = plt.subplots(figsize=(10,10))
zipdf.plot(column="label_y", cmap="plasma", figsize=(15,10), ax=ax, edgecolor='k')
ax.set_title("Agglomerative cluster on the NYC Business Establishment")
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
ax.set_axis_bgcolor('white')
# Out:
# /Users/cihe/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.

# %% [markdown]
# Fig.5 Plot the Hierarchy result on NYC geomap

# %% [markdown]
# Interpretation:
# The result of the two clustering methods are very similar. The difference of the two plots may caused by the randomness of the two algorithmns. And kmeans results also depend on the number of clusters.
# From the maps we can see most of the zipcode regions follow the same pattern over the years, however the small part of the zipcodes have different patterns. We can see the JFK and LGA airports are in the same group, east new york in Brooklyn and williamsburg are in the same group might because of their economy taking off. Interesting thing is in the kmeans method, the yellow cluster are the changing areas are the areas with many new immigrants/residents.
